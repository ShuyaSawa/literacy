# %% [markdown]
# <a href="https://colab.research.google.com/github/ShuyaSawa/literacy/blob/main/chapters/10.4/zip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [矢吹太朗『Webのしくみ』（サイエンス社, 2020）](https://github.com/taroyabuki/webbook)
#
# 下のアイコンをクリックすれば，この文書に掲載されているコードを，Google Colab上で実行できます．（Googleのアカウントが必要です．）
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taroyabuki/webbook/blob/master/chapters/10.4/zip.ipynb)

# %% [markdown]
# # 郵便番号データベースによる体験SQL
#
# 郵便番号データを使って，SQLでの検索を体験します．
#
# まずは準備です．
# 作成済みのデータベースを読み込んで，操作できるようにします．
# この部分は，理解せずに実行するだけでかまいません．
# （もちろん，理解しようとしてもかまいません．理解してもかまいません．）
#
# コードにカーソルを置いて，左側の▶ボタンをクリックするかShift+Enterで実行してください．

# %%
# このセルは準備のためのものなので，理解できなくてかまいません．
# !wget --quiet https://github.com/taroyabuki/webbook/raw/master/chapters/10.4/zip.sqlite3
import pandas as pd
import sqlite3
con = sqlite3.connect('zip.sqlite3')
def 実行(sql): return pd.read_sql_query(sql, con)

# %% [markdown]
# ## 例1：全データ取得
#
# まずは，
#
# ```
# zipという表から，
# すべての列を取り出す．
# ```
#
# という操作をしてみます．
# 次のように翻訳します．
#
# ```
# zipという表から， → from zip
# すべての列を取り出す． → select *
# ```
#
# 並び替えてSQL文とします．
#
# ```
# select *
# from zip
# ```
#
# 実行します．
#
# ```
# 実行('''
# SQL文
# ''')
# ```
#
# ↑のように書くと，SQL文が実行されるようにしてあります．
# ですから，ここで作ったSQL文は，次のように実行します．

# %%
実行('''
select *
from zip
''')
# Out:
#            code address1  address2      address3 address4         office
# 0       0600000      北海道    札幌市中央区    以下に掲載がない場合
# 1       0640941      北海道    札幌市中央区           旭ケ丘
# 2       0600041      北海道    札幌市中央区           大通東
# 3       0600042      北海道    札幌市中央区   大通西（１〜１９丁目）
# 4       0640820      北海道    札幌市中央区  大通西（２０〜２８丁目）
# ...         ...      ...       ...           ...      ...            ...
# 147103  9010496      沖縄県   島尻郡八重瀬町           字富盛     ２６０８    陸上自衛隊　与座分屯地
# 147104  9010592      沖縄県   島尻郡八重瀬町          字具志頭      １番地  八重瀬町役場　具志頭出張所
# 147105  9060692      沖縄県   宮古郡多良間村           字仲筋     ９９−２         多良間村役場
# 147106  9071292      沖縄県   八重山郡竹富町           字小浜     ２９３０    株式会社　はいむるぶし
# 147107  9071892      沖縄県  八重山郡与那国町          字与那国      １２９         与那国町役場
#
# [147108 rows x 6 columns]

# %% [markdown]
# ## 例2：件数
#
# `select count(*)`として，件数を得ます．補足：例1の結果にも表示されていますが，それはSQLではなくPythonによるものです．

# %%
実行('''
select count(*)
from zip
''')
# Out:
#    count(*)
# 0    147108

# %% [markdown]
# ## 例3：条件
#
# `where 条件`として，条件を設定します．
# 「where」は「場所」というよりは「場合」のことだと考えましょう．

# %% [markdown]
# ### 例3.1：完全一致
#
# 等号は`=`，等号否定は`!=`や`<>`です．

# %%
実行('''
select *
from zip
where code = '2758588'
''')
# Out:
#       code address1 address2 address3 address4             office
# 0  2758588      千葉県     習志野市      津田沼  ２丁目１７−１  学校法人　千葉工業大学　津田沼校舎

# %% [markdown]
# ### 例3.2 部分一致
#
# 任意の文字列を「`%`」で表し，「`%`」を含む文字列との比較を`like`や`not like`で行います．
#
# 27から始まる郵便番号を検索します．

# %%
実行('''
select *
from zip
where code like '27%'
''')
# Out:
#          code address1 address2    address3 address4        office
# 0     2720000      千葉県      市川市  以下に掲載がない場合
# 1     2720143      千葉県      市川市         相之川
# 2     2720144      千葉県      市川市          新井
# 3     2720106      千葉県      市川市         伊勢宿
# 4     2720034      千葉県      市川市          市川
# ...       ...      ...      ...         ...      ...           ...
# 1177  2701493      千葉県      白井市          桜台     １丁目４       社会保険大学校
# 1178  2701492      千葉県      白井市           復     １１２３         白井市役所
# 1179  2701496      千葉県      白井市          桜台     １丁目２  信組情報サービス　（株）
# 1180  2701495      千葉県      白井市           中    ３０５−１     フクダ電子　（株）
# 1181  2701592      千葉県    印旛郡栄町         安食台    １丁目２番          栄町役場
#
# [1182 rows x 6 columns]

# %%
実行('''
select count(*)
from zip
where code like '27%'
''')
# Out:
#    count(*)
# 0      1182

# %% [markdown]
# ### 例3.3 条件の組合せ
#
# 条件を組み合わせるときは，`and`や`or`を使います．

# %%
実行('''
select *
from zip
where address1 = '北海道' and address2 like '%中央区%'
''')
# Out:
#         code address1 address2      address3       address4  \
# 0    0600000      北海道   札幌市中央区    以下に掲載がない場合
# 1    0640941      北海道   札幌市中央区           旭ケ丘
# 2    0600041      北海道   札幌市中央区           大通東
# 3    0600042      北海道   札幌市中央区   大通西（１〜１９丁目）
# 4    0640820      北海道   札幌市中央区  大通西（２０〜２８丁目）
# ..       ...      ...      ...           ...            ...
# 294  0648512      北海道   札幌市中央区          南一条西       ２５丁目１番１号
# 295  0648543      北海道   札幌市中央区          南十条西       １丁目１番５０号
# 296  0648522      北海道   札幌市中央区        南二十二条西  ９丁目アートパレスビル３Ｆ
# 297  0648510      北海道   札幌市中央区        南二十六条西           １０丁目
# 298  0648546      北海道   札幌市中央区          南九条西           １４丁目
#
#                   office
# 0
# 1
# 2
# 3
# 4
# ..                   ...
# 294       三井道路　（株）　北海道支社
# 295        ヤマハ　（株）　北海道支店
# 296  （有）　日本書道評論社　北海道書道協会
# 297        陸上自衛隊　北部方面総監部
# 298    ロッテ商事　（株）　北海道統轄支店
#
# [299 rows x 6 columns]

# %% [markdown]
# ### 練習
#
# officeに「千葉工」を含むデータの件数を求めてみましょう．

# %%
# ここにコードを書いて，実行して試してみてください．（いろいろ試したい場合は，左上の「＋ コード」をクリックして，セルを追加するといいでしょう．）
実行('''
select count(*)
from zip
where office like '%千葉工%'
''')
# Out:
#    count(*)
# 0        18

# %% [markdown]
# # 補足：Pythonだけで完結させる（やらなくていいです）
#
# Pythonは基本的には手続き型のプログラミング言語ですが，表形式のデータを宣言的に扱うしくみが用意されています．

# %%
# 準備
import pandas as pd
data = pd.read_csv('https://github.com/taroyabuki/webbook/raw/master/chapters/10.4/zip.csv',
                   converters={0:str},    # 0列目は文字列
                   keep_default_na=False) # 空白をNaNにしない

# %%
# 全データ
data
# Out:
#            code address1  address2      address3 address4         office
# 0       0600000      北海道    札幌市中央区    以下に掲載がない場合
# 1       0640941      北海道    札幌市中央区           旭ケ丘
# 2       0600041      北海道    札幌市中央区           大通東
# 3       0600042      北海道    札幌市中央区   大通西（１〜１９丁目）
# 4       0640820      北海道    札幌市中央区  大通西（２０〜２８丁目）
# ...         ...      ...       ...           ...      ...            ...
# 147103  9010496      沖縄県   島尻郡八重瀬町           字富盛     ２６０８    陸上自衛隊　与座分屯地
# 147104  9010592      沖縄県   島尻郡八重瀬町          字具志頭      １番地  八重瀬町役場　具志頭出張所
# 147105  9060692      沖縄県   宮古郡多良間村           字仲筋     ９９−２         多良間村役場
# 147106  9071292      沖縄県   八重山郡竹富町           字小浜     ２９３０    株式会社　はいむるぶし
# 147107  9071892      沖縄県  八重山郡与那国町          字与那国      １２９         与那国町役場
#
# [147108 rows x 6 columns]

# %%
# 完全一致
data.query("code == '2758588'")
# Out:
#            code address1 address2 address3 address4             office
# 129287  2758588      千葉県     習志野市      津田沼  ２丁目１７−１  学校法人　千葉工業大学　津田沼校舎

# %%
# 部分一致（27で始まる郵便番号）
# startswithをcontainsにすると「・・・を含む」になる．
# startswithをendswithにすると「・・・で終わる」になる．
data.query("code.str.startswith('27')", engine='python')
# Out:
#            code address1 address2    address3 address4        office
# 33870   2720000      千葉県      市川市  以下に掲載がない場合
# 33871   2720143      千葉県      市川市         相之川
# 33872   2720144      千葉県      市川市          新井
# 33873   2720106      千葉県      市川市         伊勢宿
# 33874   2720034      千葉県      市川市          市川
# ...         ...      ...      ...         ...      ...           ...
# 129469  2701493      千葉県      白井市          桜台     １丁目４       社会保険大学校
# 129470  2701492      千葉県      白井市           復     １１２３         白井市役所
# 129471  2701496      千葉県      白井市          桜台     １丁目２  信組情報サービス　（株）
# 129472  2701495      千葉県      白井市           中    ３０５−１     フクダ電子　（株）
# 129510  2701592      千葉県    印旛郡栄町         安食台    １丁目２番          栄町役場
#
# [1182 rows x 6 columns]

# %%
# 条件の組合せ
data.query("address1 == '北海道' and address2.str.contains('中央区')", engine='python')
# Out:
#            code address1 address2      address3       address4  \
# 0       0600000      北海道   札幌市中央区    以下に掲載がない場合
# 1       0640941      北海道   札幌市中央区           旭ケ丘
# 2       0600041      北海道   札幌市中央区           大通東
# 3       0600042      北海道   札幌市中央区   大通西（１〜１９丁目）
# 4       0640820      北海道   札幌市中央区  大通西（２０〜２８丁目）
# ...         ...      ...      ...           ...            ...
# 124894  0648512      北海道   札幌市中央区          南一条西       ２５丁目１番１号
# 124895  0648543      北海道   札幌市中央区          南十条西       １丁目１番５０号
# 124896  0648522      北海道   札幌市中央区        南二十二条西  ９丁目アートパレスビル３Ｆ
# 124897  0648510      北海道   札幌市中央区        南二十六条西           １０丁目
# 124898  0648546      北海道   札幌市中央区          南九条西           １４丁目
#
#                      office
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 124894       三井道路　（株）　北海道支社
# 124895        ヤマハ　（株）　北海道支店
# 124896  （有）　日本書道評論社　北海道書道協会
# 124897        陸上自衛隊　北部方面総監部
# 124898    ロッテ商事　（株）　北海道統轄支店
#
# [299 rows x 6 columns]

# %% [markdown]
# ### 練習
#
# officeに「千葉工」を含むデータの件数を求めてみましょう．

# %%
# ここにコードを書いて，実行して試してみてください．（いろいろ試したい場合は，左上の「＋ コード」をクリックして，セルを追加するといいでしょう．）
data.query("office.str.contains('千葉工')", engine='python')
# Out:
#            code address1 address2 address3 address4                    office
# 129078  2618530      千葉県   千葉市美浜区       新港       ２２            山崎製パン　株式会社千葉工場
# 129287  2758588      千葉県     習志野市      津田沼  ２丁目１７−１         学校法人　千葉工業大学　津田沼校舎
# 129351  2908566      千葉県      市原市     五井海岸       １０             旭硝子　株式会社　千葉工場
# 129358  2908560      千葉県      市原市    五井南海岸    １１番地１          ＫＨネオケム　株式会社　千葉工場
# 129361  2908585      千葉県      市原市    八幡海岸通       １２             ＤＩＣ　株式会社　千葉工場
# 129362  2908588      千葉県      市原市    五井南海岸        ６          電気化学工業　株式会社　千葉工場
# 129363  2908530      千葉県      市原市    五井南海岸     １２−８            日本曹達　株式会社　千葉工場
# 129364  2908610      千葉県      市原市    八幡海岸通       １３           不二サッシ　株式会社　千葉工場
# 129365  2908511      千葉県      市原市    八幡海岸通        ７       富士電機システムズ　株式会社　千葉工場
# 129367  2908503      千葉県      市原市    五井南海岸        ３          丸善石油化学　株式会社　千葉工場
# 129369  2908550      千葉県      市原市    五井南海岸      ８−１       ＵＢＥエラストマー　株式会社　千葉工場
# 129376  2990195      千葉県      市原市     姉崎海岸      ５−１          住友化学工業　株式会社　千葉工場
# 129377  2990196      千葉県      市原市     千種海岸      ２の１              東レ　株式会社　千葉工場
# 129378  2990197      千葉県      市原市     姉崎海岸        ６           日本板硝子　株式会社　千葉工場
# 129445  2990297      千葉県     袖ケ浦市       中袖      ５−１  旭化成ケミカルズ　株式会社　川崎製造所　千葉工場
# 129449  2990295      千葉県     袖ケ浦市       北袖      ９−１            住友化学　株式会社　千葉工場
# 129503  2891592      千葉県      山武市   松尾町下大蔵   ４５３番地１         ＰＤＲファーマ　株式会社　千葉工場
# 129526  2970292      千葉県   長生郡長柄町       鴇谷      １６３       大崎電気システムズ　株式会社　千葉工場

# %% [markdown]
# # 補足：シェルだけで完結させる（やらなくていいです）
#
# ここでやっている程度の話は，Pythonのような汎用プログラミング言語を持ち出すまでもなく，シェルスクリプトという簡易的なプログラムでも解決できます．
#
# 参考書
#
# - [カーニハン，パイク『UNIXプログラミング環境』](https://calil.jp/search?q=UNIX%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E7%92%B0%E5%A2%83)（1985年版と2017年版のどちらを参照してもかまいません．）
# - [エイホほか『プログラミング言語AWK』](https://calil.jp/search?q=%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E8%A8%80%E8%AA%9EAWK)（第1版と第2版のどちらを参照してもかまいません．）
#
# 以下，「`-F,`」は「コンマで分割する」という意味です．

# %%
# ツールのインストール（管理者権限が必要）
# !apt-get install gawk | tail -n 1
# Out:
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# 準備
# !wget --quiet https://github.com/taroyabuki/webbook/raw/master/chapters/10.4/zip.csv

# %%
# データの形式
# !head zip.csv

# %%
# 件数（この結果から見出しの分つまり1を引く）
# !wc -l zip.csv

# %%
# 完全一致
# !awk -F, '$1=="\"2758588\""' zip.csv

# %%
# 部分一致（27で始まる郵便番号．headを付けて最初の方を表示する．）
# !awk -F, '$1~/"27/' zip.csv | head

# %%
# 部分一致（「 | wc -l」を付けて件数を数える．）
# !awk -F, '$1~/"27/' zip.csv | wc -l

# %%
# 条件の組合せ
# !awk -F, '$2=="\"北海道\"" && $3~/中央区/' zip.csv | head

# %%
# !awk -F, '$2=="\"北海道\"" && $3~/中央区/' zip.csv | wc -l

# %% [markdown]
# ### 練習
#
# officeに「千葉工」を含むデータの件数を求めてみましょう．

# %%
# ここにコードを書いて，実行して試してみてください．（いろいろ試したい場合は，左上の「＋ コード」をクリックして，セルを追加するといいでしょう．）

# %% [markdown]
# # （気が強い人のための）補足：データベースの作り方
#
# **最新版のデータを使うため，上に掲載したのとは，違う結果を得る可能性があります．**
#
# 日本の郵便番号のデータは，https://www.post.japanpost.jp/zipcode/download.html で，CSV形式で公開されています．
# このデータをダウンロードして，データベースを作ります．
#
# SQLite3というデータベース管理システムを使います．
# SQLite3の操作はPythonで行います．

# %%
# ツールのインストール（管理者権限が必要）
# !apt-get install nkf gawk -y | tail -n 1
# Out:
# Processing triggers for man-db (2.10.2-1) ...

# %%
# 準備
# !rm -f *.zip *.csv *.CSV # 作業ファイルの削除

# ダウンロード
# !wget --quiet https://www.post.japanpost.jp/zipcode/dl/kogaki/zip/ken_all.zip
# !wget --quiet https://www.post.japanpost.jp/zipcode/dl/jigyosyo/zip/jigyosyo.zip

# 展開
# !unzip -q ken_all.zip
# !unzip -q jigyosyo.zip

# zip.csvの作成
# !echo 'code,address1,address2,address3,address4,office' > zip.csv

# 文字コードの変換と必要なデータの抽出
# !nkf -Lu -w KEN_ALL.CSV | gawk -F, -v OFS="," '{print $3,$7,$8,$9,"\"\"","\"\""}'  >> zip.csv
# !nkf -Lu -w JIGYOSYO.CSV | gawk -F, -v OFS="," '{print $8,$4,$5,$6,$7,$3}' >> zip.csv

# %%
# 元のデータはこんな感じ（nkf -wでUTF-8に変換してから，headで先頭部分を表示）
# !nkf -w KEN_ALL.CSV | head

# %%
# 抽出後のデータはこんな感じ
# !head zip.csv

# %%
# データの件数
# !wc -l zip.csv

# %% [markdown]
# 一度Pythonで読み込んで，SQLiteのデータベースにデータを挿入する．（zip.sqlite3というファイルができる．これが，作りたかったものである．）

# %%
# Pythonで読み込む
import pandas as pd
data = pd.read_csv('zip.csv', converters={0:str}, keep_default_na=False)

import sqlite3
# !rm -f zip.sqlite3                   # 既存のデータベースの削除
con = sqlite3.connect('zip.sqlite3') # データベースの作成
data.to_sql('zip', con, index=False) # データの挿入
cur = con.cursor()                   # インデックスの作成（番号での検索を高速化するため）
cur.execute('create index code_idx on zip (code)')

# %%
# 動作確認2
pd.read_sql_query('select * from zip limit 10', con)

# %%
# データベースを閉じて終了
con.close()
